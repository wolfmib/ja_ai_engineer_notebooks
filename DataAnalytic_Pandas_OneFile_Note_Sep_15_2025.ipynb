# %%
import datetime
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import plotly.express as px

# %%
## this note shall keep one file and collect all you feel good to here first, don not seperate into other labs, keep focus on this one file

#check data
df.dtypes

# %%
# conver date
df['date'] = pd.to_datetime(df['date'])

# %%
# checkin missing data, if not 0, fixed
df.isnull().sum()

# %%
# check range
df.describe(include ='all')

# %%
# checking date-range
full_date_range = pd.date_range(start='2018-01-01',end = '2018-12-31')

# checking data
full_date_range.difference(df['date'])

# %%
# make box plot
sns.boxplot(y= df['number_of_strikes'])

# skew..

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# use showfliers
sns.boxplot(y=df['number_of_strikes'],showfliers = False)

# %%
# quick note
df[['lat','lng']].drop_duplicates()

px.scatter_geo(df_point, lat ='lat', lon = 'lng')
plt.show()
